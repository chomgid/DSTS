# %% [markdown]
# # 데이터 및 모듈 불러오기

# %%
from synthesize import *
from calibration import *
rawdata = pd.read_csv("Energy Data/seoul_powerusage_data.csv", index_col=None)
rawdata=rawdata.drop(columns=['Unnamed: 0','Year','Month'])
ori_data = rawdata.to_numpy().T

rawdata
# Out:
#     광진구 Power Usage  양천구 Power Usage  도봉구 Power Usage  서대문구 Power Usage  \
# 0            189.15           232.87           220.63            193.39
# 1            198.32           243.41           236.12            202.48
# 2            205.93           249.14           244.78            214.99
# 3            220.62           264.87           263.12            231.71
# 4            223.33           265.88           266.32            233.44
# ..              ...              ...              ...               ...
# 94           316.31           374.57           330.10            335.96
# 95           269.19           327.19           273.71            278.66
# 96           194.06           241.08           213.00            213.93
# 97           188.02           235.18           216.69            212.03
# 98           200.32           248.17           231.23            228.77
#
#     중구 Power Usage  중랑구 Power Usage  송파구 Power Usage  종로구 Power Usage  \
# 0           195.46           200.37           223.35           186.85
# 1           204.73           211.97           235.13           195.69
# 2           215.13           220.39           255.81           206.61
# 3           230.94           237.81           256.92           223.02
# 4           234.51           242.77           259.30           226.81
# ..             ...              ...              ...              ...
# 94          321.86           313.06           389.63           297.59
# 95          264.35           271.00           337.59           251.76
# 96          194.77           202.79           248.02           185.38
# 97          191.85           198.28           241.91           182.94
# 98          210.96           211.87           255.26           202.05
#
#     용산구 Power Usage  은평구 Power Usage  ...  영등포구 Power Usage  성북구 Power Usage  \
# 0            217.64           206.80  ...            198.58           212.13
# 1            226.23           218.16  ...            206.92           223.14
# 2            235.79           226.33  ...            217.70           231.84
# 3            253.57           243.12  ...            233.51           248.67
# 4            257.62           246.93  ...            234.46           253.84
# ..              ...              ...  ...               ...              ...
# 94           380.18           339.00  ...            325.43           340.31
# 95           319.96           293.19  ...            276.05           307.13
# 96           224.57           221.96  ...            203.22           229.73
# 97           216.23           218.36  ...            196.55           220.52
# 98           231.43           233.16  ...            211.51           234.29
#
#     마포구 Power Usage  금천구 Power Usage  관악구 Power Usage  강동구 Power Usage  \
# 0            196.40           190.56           173.26           210.39
# 1            205.48           201.78           182.78           223.84
# 2            212.41           209.14           190.24           233.30
# 3            228.83           226.29           203.35           249.36
# 4            231.62           229.08           208.97           251.37
# ..              ...              ...              ...              ...
# 94           350.11           300.27           266.76           360.24
# 95           297.99           256.49           230.15           304.14
# 96           218.18           191.79           169.92           224.50
# 97           210.18           187.12           163.65           220.52
# 98           225.70           199.49           173.14           222.16
#
#     성동구 Power Usage  강북구 Power Usage  구로구 Power Usage  동작구 Power Usage
# 0            218.32           197.36           208.82           194.67
# 1            228.28           208.84           219.72           204.28
# 2            234.82           217.25           227.88           212.23
# 3            251.73           234.07           243.91           224.82
# 4            257.23           239.73           246.98           228.51
# ..              ...              ...              ...              ...
# 94           367.01           300.38           336.00           321.29
# 95           331.21           262.05           286.56           276.78
# 96           239.84           196.40           214.17           204.30
# 97           226.13           193.16           210.08           197.49
# 98           240.30           205.35           223.54           208.71
#
# [99 rows x 25 columns]

# %%
aug_data = synthesize(ori_data)
synth_data = calibration(ori_data, aug_data)
# Out:
# each_iter_error
# 2.233068753908782
# each_iter_error
# 2.233064146135291
# each_iter_error
# 2.2330580024412257
# each_iter_error
# 2.2330503228309055
# each_iter_error
# 2.2330411073093615
# each_iter_error
# 2.2330303558835
# each_iter_error
# 2.2330180685609946
# each_iter_error
# 2.2330042453509975
# each_iter_error
# 2.2329888862636267
# each_iter_error
# 2.2329719913102224
# each_iter_error
# 2.232953560503489
# each_iter_error
# 2.232933593856984
# each_iter_error
# 2.232912091386112
# each_iter_error
# 2.232889053106817
# each_iter_error
# 2.232864479036863
# tot error
# 184.23522291050176
# each_iter_error
# 2.334164878080287
# each_iter_error
# 2.3341599353556717
# each_iter_error
# 2.3341533450604857
# each_iter_error
# 2.33414510719939
# each_iter_error
# 2.334135221778695
# each_iter_error
# 2.334123688805505
# each_iter_error
# 2.3341105082882336
# each_iter_error
# 2.334095680237283
# each_iter_error
# 2.334079204664164
# each_iter_error
# 2.3340610815808986
# each_iter_error
# 2.3340413110018403
# each_iter_error
# 2.334019892942166
# each_iter_error
# 2.333996827418474
# each_iter_error
# 2.3339721144486134
# each_iter_error
# 2.3339457540520243
# tot error
# 184.21293265793588
# each_iter_error
# 2.14575227407704
# each_iter_error
# 2.1457477186470157
# each_iter_error
# 2.1457416447444757
# each_iter_error
# 2.1457340523743937
# each_iter_error
# 2.145724941542227
# each_iter_error
# 2.145714312254995
# each_iter_error
# 2.1457021645210546
# each_iter_error
# 2.1456884983491307
# each_iter_error
# 2.145673313750393
# each_iter_error
# 2.145656610736552
# each_iter_error
# 2.1456383893202826
# each_iter_error
# 2.145618649516365
# each_iter_error
# 2.1455973913398907
# each_iter_error
# 2.1455746148076855
# each_iter_error
# 2.1455503199373425
# tot error
# 184.19336458130056
# each_iter_error
# 2.757885161583715
# each_iter_error
# 2.7578794208377815
# each_iter_error
# 2.7578717665149384
# each_iter_error
# 2.757862198619705
# each_iter_error
# 2.7578507171593856
# each_iter_error
# 2.757837322142308
# each_iter_error
# 2.75782201357805
# each_iter_error
# 2.757804791477895
# each_iter_error
# 2.757785655855031
# each_iter_error
# 2.7577646067238675
# each_iter_error
# 2.7577416441000935
# each_iter_error
# 2.7577167680015577
# each_iter_error
# 2.75768997844699
# each_iter_error
# 2.7576612754567407
# each_iter_error
# 2.7576306590534614
# tot error
# 184.17027196446764
# each_iter_error
# 3.401696194344936
# each_iter_error
# 3.4016889865388293
# each_iter_error
# 3.401679376135945
# each_iter_error
# 3.4016673631425363
# each_iter_error
# 3.4016529475670154
# each_iter_error
# 3.401636129419245
# each_iter_error
# 3.401616908712299
# each_iter_error
# 3.401595285460303
# each_iter_error
# 3.4015712596798267
# each_iter_error
# 3.401544831388776
# each_iter_error
# 3.4015160006082112
# each_iter_error
# 3.401484767360074
# each_iter_error
# 3.4014511316689493
# each_iter_error
# 3.401415093561127
# each_iter_error
# 3.401376653064972
# tot error
# 184.14255349917048
# each_iter_error
# 2.803272192819122
# each_iter_error
# 2.80326641308406
# each_iter_error
# 2.8032587067744714
# each_iter_error
# 2.8032490738957563
# each_iter_error
# 2.803237514454622
# each_iter_error
# 2.803224028459141
# each_iter_error
# 2.8032086159188054
# each_iter_error
# 2.8031912768453537
# each_iter_error
# 2.8031720112511778
# each_iter_error
# 2.803150819150602
# each_iter_error
# 2.8031277005599122
# each_iter_error
# 2.803102655496417
# each_iter_error
# 2.8030756839791877
# each_iter_error
# 2.803046786028858
# each_iter_error
# 2.8030159616674553
# tot error
# 184.116833386756
# each_iter_error
# 2.8268860481510956
# each_iter_error
# 2.826880109258582
# each_iter_error
# 2.8268721907396355
# each_iter_error
# 2.8268622925992872
# each_iter_error
# 2.8268504148445572
# each_iter_error
# 2.8268365574841425
# each_iter_error
# 2.826820720527877
# each_iter_error
# 2.826802903987385
# each_iter_error
# 2.826783107876338
# each_iter_error
# 2.826761332209429
# each_iter_error
# 2.826737577003456
# each_iter_error
# 2.826711842276211
# each_iter_error
# 2.8266841280475603
# each_iter_error
# 2.826654434338934
# each_iter_error
# 2.8266227611731267
# tot error
# 184.09056335163626
# each_iter_error
# 2.125702370952638
# each_iter_error
# 2.125698031833309
# each_iter_error
# 2.1256922463446415
# each_iter_error
# 2.1256850144904718
# each_iter_error
# 2.1256763362757454
# each_iter_error
# 2.1256662117070277
# each_iter_error
# 2.125654640791396
# each_iter_error
# 2.1256416235371773
# each_iter_error
# 2.1256271599540923
# each_iter_error
# 2.1256112500526285
# each_iter_error
# 2.12559389384478
# each_iter_error
# 2.1255750913433076
# each_iter_error
# 2.125554842562167
# each_iter_error
# 2.1255331475166486
# each_iter_error
# 2.125510006222669
# tot error
# 184.06953600728943
# each_iter_error
# 1.9414853633363407
# each_iter_error
# 1.9414813464832719
# each_iter_error
# 1.9414759906828465
# each_iter_error
# 1.9414692959391857
# each_iter_error
# 1.941461262256638
# each_iter_error
# 1.9414518896412574
# each_iter_error
# 1.9414411780993817
# each_iter_error
# 1.9414291276394238
# each_iter_error
# 1.941415738270024
# each_iter_error
# 1.9414010100008738
# each_iter_error
# 1.9413849428426602
# each_iter_error
# 1.941367536807661
# each_iter_error
# 1.941348791908382
# each_iter_error
# 1.9413287081587782
# each_iter_error
# 1.9413072855738847
# tot error
# 184.05070879588314
# each_iter_error
# 1.3051761968156086
# each_iter_error
# 1.305173295288398
# each_iter_error
# 1.3051694265890887
# each_iter_error
# 1.305164590720807
# each_iter_error
# 1.3051587876877306
# each_iter_error
# 1.3051520174945779
# each_iter_error
# 1.3051442801468909
# each_iter_error
# 1.305135575651093
# each_iter_error
# 1.3051259040136358
# each_iter_error
# 1.3051152652429323
# each_iter_error
# 1.3051036593468552
# each_iter_error
# 1.3050910863355227
# each_iter_error
# 1.3050775462184845
# each_iter_error
# 1.3050630390066829
# each_iter_error
# 1.305047564711714
# tot error
# 184.03899883189558
# each_iter_error
# 0.9103507083077602
# each_iter_error
# 0.9103485037105088
# each_iter_error
# 0.9103455642514291
# each_iter_error
# 0.9103418899329085
# each_iter_error
# 0.910337480758642
# each_iter_error
# 0.9103323367324947
# each_iter_error
# 0.9103264578593553
# each_iter_error
# 0.9103198441442828
# each_iter_error
# 0.91031249559353
# each_iter_error
# 0.9103044122131223
# each_iter_error
# 0.9102955940107904
# each_iter_error
# 0.9102860409938103
# each_iter_error
# 0.9102757531709358
# each_iter_error
# 0.910264730550864
# each_iter_error
# 0.9102529731430877
# tot error
# 184.03281894416392
# each_iter_error
# 2.578398207977159
# each_iter_error
# 2.5783927601176515
# each_iter_error
# 2.5783854963102613
# each_iter_error
# 2.578376416559763
# each_iter_error
# 2.5783655208729215
# each_iter_error
# 2.5783528092573533
# each_iter_error
# 2.5783382817230063
# each_iter_error
# 2.5783219382803395
# each_iter_error
# 2.5783037789419154
# each_iter_error
# 2.5782838037210922
# each_iter_error
# 2.578262012633047
# each_iter_error
# 2.578238405694151
# each_iter_error
# 2.578212982922537
# each_iter_error
# 2.578185744337418
# each_iter_error
# 2.5781566899593145
# tot error
# 184.01208713644778
# each_iter_error
# 1.7523351383044599
# each_iter_error
# 1.752331597876264
# each_iter_error
# 1.7523268773085192
# each_iter_error
# 1.7523209766050059
# each_iter_error
# 1.7523138957696744
# each_iter_error
# 1.7523056348072146
# each_iter_error
# 1.7522961937239927
# each_iter_error
# 1.7522855725268585
# each_iter_error
# 1.752273771223571
# each_iter_error
# 1.7522607898223725
# each_iter_error
# 1.7522466283329265
# each_iter_error
# 1.7522312867656922
# each_iter_error
# 1.7522147651318676
# each_iter_error
# 1.7521970634435604
# each_iter_error
# 1.7521781817134752
# tot error
# 183.99494559369427
# each_iter_error
# 1.7392846029141253
# each_iter_error
# 1.7392808748413984
# each_iter_error
# 1.7392759040816657
# each_iter_error
# 1.7392696906387357
# each_iter_error
# 1.7392622345178097
# each_iter_error
# 1.7392535357246572
# each_iter_error
# 1.7392435942653606
# each_iter_error
# 1.7392324101485315
# each_iter_error
# 1.739219983382469
# each_iter_error
# 1.7392063139771778
# each_iter_error
# 1.7391914019432306
# each_iter_error
# 1.7391752472926783
# each_iter_error
# 1.7391578500378557
# each_iter_error
# 1.7391392101928886
# each_iter_error
# 1.7391193277718457
# tot error
# 183.97821755780075
# each_iter_error
# 1.9081779690231713
# each_iter_error
# 1.908173954313412
# each_iter_error
# 1.908168601371301
# each_iter_error
# 1.9081619102006755
# each_iter_error
# 1.9081538808067933
# each_iter_error
# 1.9081445131951114
# each_iter_error
# 1.9081338073735594
# each_iter_error
# 1.908121763349726
# each_iter_error
# 1.9081083811332746
# each_iter_error
# 1.908093660734039
# each_iter_error
# 1.9080776021636723
# each_iter_error
# 1.9080602054343387
# each_iter_error
# 1.9080414705595672
# each_iter_error
# 1.908021397553938
# each_iter_error
# 1.9079999864326567
# tot error
# 183.96058218313846
# each_iter_error
# 2.760450490028205
# each_iter_error
# 2.7604446259114184
# each_iter_error
# 2.760436807093811
# each_iter_error
# 2.7604270335809815
# each_iter_error
# 2.7604153053801213
# each_iter_error
# 2.760401622499529
# each_iter_error
# 2.7603859849499486
# each_iter_error
# 2.7603683927428335
# each_iter_error
# 2.76034884589194
# each_iter_error
# 2.7603273444123317
# each_iter_error
# 2.760303888320692
# each_iter_error
# 2.7602784776347846
# each_iter_error
# 2.7602511123750446
# each_iter_error
# 2.7602217925625894
# each_iter_error
# 2.760190518220753
# tot error
# 183.93663161674385
# each_iter_error
# 3.242607482496311
# each_iter_error
# 3.2426002298191463
# each_iter_error
# 3.2425905595886206
# each_iter_error
# 3.24257847181201
# each_iter_error
# 3.2425639664984374
# each_iter_error
# 3.242547043659158
# each_iter_error
# 3.242527703307246
# each_iter_error
# 3.2425059454586176
# each_iter_error
# 3.2424817701306665
# each_iter_error
# 3.2424551773434587
# each_iter_error
# 3.2424261671186514
# each_iter_error
# 3.242394739480403
# each_iter_error
# 3.242360894454606
# each_iter_error
# 3.2423246320697103
# each_iter_error
# 3.242285952356241
# tot error
# 183.90859158453355
# each_iter_error
# 2.209354807318846
# each_iter_error
# 2.2093501847378434
# each_iter_error
# 2.2093440213004953
# each_iter_error
# 2.2093363170112355
# each_iter_error
# 2.209327071875663
# each_iter_error
# 2.209316285900286
# each_iter_error
# 2.2093039590936314
# each_iter_error
# 2.2092900914643963
# each_iter_error
# 2.2092746830233523
# each_iter_error
# 2.209257733782266
# each_iter_error
# 2.209239243753757
# each_iter_error
# 2.209219212952405
# each_iter_error
# 2.2091976413931036
# each_iter_error
# 2.209174529092678
# each_iter_error
# 2.209149876069091
# tot error
# 183.8866127432363
# each_iter_error
# 2.2423760032862106
# each_iter_error
# 2.2423710881032264
# each_iter_error
# 2.24236453453031
# each_iter_error
# 2.242356342572606
# each_iter_error
# 2.2423465122367077
# each_iter_error
# 2.2423350435297493
# each_iter_error
# 2.242321936460826
# each_iter_error
# 2.242307191040311
# each_iter_error
# 2.2422908072799146
# each_iter_error
# 2.242272785192398
# each_iter_error
# 2.2422531247924837
# each_iter_error
# 2.2422318260958036
# each_iter_error
# 2.2422088891191265
# each_iter_error
# 2.2421843138810402
# each_iter_error
# 2.242158100401724
# tot error
# 183.86472828274302
# each_iter_error
# 1.7786757378367497
# each_iter_error
# 1.7786719013630545
# each_iter_error
# 1.7786667860691239
# each_iter_error
# 1.7786603919581694
# each_iter_error
# 1.7786527190355912
# each_iter_error
# 1.7786437673071873
# each_iter_error
# 1.7786335367797506
# each_iter_error
# 1.7786220274614664
# each_iter_error
# 1.7786092393611455
# each_iter_error
# 1.7785951724889344
# each_iter_error
# 1.7785798268557187
# each_iter_error
# 1.7785632024736344
# each_iter_error
# 1.7785452993555282
# each_iter_error
# 1.7785261175159235
# each_iter_error
# 1.7785056569695996
# tot error
# 183.84594697803362
# each_iter_error
# 1.8721545148970336
# each_iter_error
# 1.872150487081825
# each_iter_error
# 1.8721451166658198
# each_iter_error
# 1.8721384036527127
# each_iter_error
# 1.8721303480477616
# each_iter_error
# 1.872120949857191
# each_iter_error
# 1.8721102090880493
# each_iter_error
# 1.8720981257486073
# each_iter_error
# 1.8720846998483864
# each_iter_error
# 1.8720699313976752
# each_iter_error
# 1.8720538204080412
# each_iter_error
# 1.8720363668918765
# each_iter_error
# 1.8720175708628801
# each_iter_error
# 1.8719974323355189
# each_iter_error
# 1.871975951325993
# tot error
# 183.8266680139472
# each_iter_error
# 0.9335611890241751
# each_iter_error
# 0.9335588683285891
# each_iter_error
# 0.9335557740718627
# each_iter_error
# 0.9335519062568096
# each_iter_error
# 0.9335472648870109
# each_iter_error
# 0.9335418499669288
# each_iter_error
# 0.9335356615016792
# each_iter_error
# 0.9335286994969749
# each_iter_error
# 0.9335209639594666
# each_iter_error
# 0.9335124548956344
# each_iter_error
# 0.9335031723140617
# each_iter_error
# 0.9334931162224223
# each_iter_error
# 0.9334822866300385
# each_iter_error
# 0.9334706835471707
# each_iter_error
# 0.9334583069835674
# tot error
# 183.818370261556
# each_iter_error
# 2.4718813910640733
# each_iter_error
# 2.471875348853871
# each_iter_error
# 2.4718672925818055
# each_iter_error
# 2.471857222254471
# each_iter_error
# 2.471845137880962
# each_iter_error
# 2.4718310394717378
# each_iter_error
# 2.4718149270398158
# each_iter_error
# 2.4717968005987814
# each_iter_error
# 2.4717766601654603
# each_iter_error
# 2.4717545057569055
# each_iter_error
# 2.4717303373933532
# each_iter_error
# 2.471704155096063
# each_iter_error
# 2.47167595888817
# each_iter_error
# 2.4716457487947423
# each_iter_error
# 2.4716135248424393
# tot error
# 183.79985814522456
# each_iter_error
# 2.3618066747868625
# each_iter_error
# 2.3618016098583325
# each_iter_error
# 2.361794856625494
# each_iter_error
# 2.3617864150927517
# each_iter_error
# 2.3617762852666147
# each_iter_error
# 2.3617644671546145
# each_iter_error
# 2.3617509607659315
# each_iter_error
# 2.3617357661109395
# each_iter_error
# 2.3617188832010356
# each_iter_error
# 2.3617003120498623
# each_iter_error
# 2.361680052671801
# each_iter_error
# 2.361658105082057
# each_iter_error
# 2.3616344692984796
# each_iter_error
# 2.361609145339685
# each_iter_error
# 2.3615821332250846
# tot error
# 183.7779952918476
# each_iter_error
# 1.8135151180861726
# each_iter_error
# 1.8135112962807796
# each_iter_error
# 1.8135062005441398
# each_iter_error
# 1.8134998308797492
# each_iter_error
# 1.8134921872927237
# each_iter_error
# 1.813483269788776
# each_iter_error
# 1.8134730783741873
# each_iter_error
# 1.8134616130572567
# each_iter_error
# 1.8134488738464256
# each_iter_error
# 1.813434860751471
# each_iter_error
# 1.8134195737833636
# each_iter_error
# 1.8134030129538985
# each_iter_error
# 1.8133851782753538
# each_iter_error
# 1.8133660697620257
# each_iter_error
# 1.813345687428182
# tot error
# 183.7588763513254
# each_iter_error
# 1.5988051490332396
# each_iter_error
# 1.598801670521027
# each_iter_error
# 1.5987970325088838
# each_iter_error
# 1.5987912350003057
# each_iter_error
# 1.5987842779998402
# each_iter_error
# 1.5987761615129443
# each_iter_error
# 1.5987668855460697
# each_iter_error
# 1.5987564501066913
# each_iter_error
# 1.598744855202824
# each_iter_error
# 1.5987321008437618
# each_iter_error
# 1.5987181870394238
# each_iter_error
# 1.5987031138009513
# each_iter_error
# 1.5986868811406225
# each_iter_error
# 1.5986694890707156
# each_iter_error
# 1.5986509376053561
# tot error
# 183.74269070721323
# each_iter_error
# 1.6761333153306737
# each_iter_error
# 1.6761297545278353
# each_iter_error
# 1.6761250067944502
# each_iter_error
# 1.676119072134469
# each_iter_error
# 1.676111950552155
# each_iter_error
# 1.6761036420531923
# each_iter_error
# 1.676094146643635
# each_iter_error
# 1.6760834643310716
# each_iter_error
# 1.676071595123517
# each_iter_error
# 1.6760585390301515
# each_iter_error
# 1.6760442960608373
# each_iter_error
# 1.6760288662268295
# each_iter_error
# 1.6760122495398377
# each_iter_error
# 1.6759944460121687
# each_iter_error
# 1.6759754556581754
# tot error
# 183.72706726401097
# each_iter_error
# 2.1936159452779407
# each_iter_error
# 2.193611242368519
# each_iter_error
# 2.193604971827426
# each_iter_error
# 2.193597133659523
# each_iter_error
# 2.1935877278704368
# each_iter_error
# 2.193576754467415
# each_iter_error
# 2.1935642134587567
# each_iter_error
# 2.1935501048543813
# each_iter_error
# 2.1935344286649183
# each_iter_error
# 2.193517184902845
# each_iter_error
# 2.1934983735811215
# each_iter_error
# 2.1934779947147263
# each_iter_error
# 2.193456048319206
# each_iter_error
# 2.193432534411869
# each_iter_error
# 2.1934074530110195
# tot error
# 183.70805073080498
# each_iter_error
# 2.274850015805441
# each_iter_error
# 2.274844983147318
# each_iter_error
# 2.2748382729418495
# each_iter_error
# 2.274829885194322
# each_iter_error
# 2.2748198199111016
# each_iter_error
# 2.274808077100346
# each_iter_error
# 2.27479465677132
# each_iter_error
# 2.274779558934654
# each_iter_error
# 2.274762783602796
# each_iter_error
# 2.2747443307886215
# each_iter_error
# 2.274724200507592
# each_iter_error
# 2.2747023927755947
# each_iter_error
# 2.274678907610081
# each_iter_error
# 2.274653745030605
# each_iter_error
# 2.2746269050572323
# tot error
# 183.6884737240009
# each_iter_error
# 1.3591651073529363
# each_iter_error
# 1.3591622173307485
# each_iter_error
# 1.3591583639711189
# each_iter_error
# 1.3591535472772023
# each_iter_error
# 1.3591477672523524
# each_iter_error
# 1.3591410239018558
# each_iter_error
# 1.359133317230203
# each_iter_error
# 1.359124647243874
# each_iter_error
# 1.3591150139491504
# each_iter_error
# 1.3591044173539615
# each_iter_error
# 1.3590928574661802
# each_iter_error
# 1.3590803342948448
# each_iter_error
# 1.3590668478496468
# each_iter_error
# 1.3590523981410456
# each_iter_error
# 1.3590369851800403
# tot error
# 183.67474574488037
# each_iter_error
# 1.4912645711488608
# each_iter_error
# 1.4912612775924288
# each_iter_error
# 1.4912568861879834
# each_iter_error
# 1.491251396938992
# each_iter_error
# 1.4912448098496043
# each_iter_error
# 1.4912371249256466
# each_iter_error
# 1.4912283421728603
# each_iter_error
# 1.4912184615990043
# each_iter_error
# 1.4912074832113547
# each_iter_error
# 1.4911954070193758
# each_iter_error
# 1.4911822330325606
# each_iter_error
# 1.4911679612614819
# each_iter_error
# 1.4911525917177357
# each_iter_error
# 1.4911361244138277
# each_iter_error
# 1.4911185593630307
# tot error
# 183.65968044417392
# each_iter_error
# 1.2390988935372604
# each_iter_error
# 1.2390961871567185
# each_iter_error
# 1.2390925786531
# each_iter_error
# 1.2390880680287921
# each_iter_error
# 1.2390826552874898
# each_iter_error
# 1.239076340433968
# each_iter_error
# 1.239069123472973
# each_iter_error
# 1.2390610044101322
# each_iter_error
# 1.2390519832523808
# each_iter_error
# 1.2390420600067102
# each_iter_error
# 1.2390312346809367
# each_iter_error
# 1.2390195072840982
# each_iter_error
# 1.2390068778251475
# each_iter_error
# 1.2389933463142597
# each_iter_error
# 1.238978912762093
# tot error
# 183.64633351009746
# each_iter_error
# 1.2057085968340857
# each_iter_error
# 1.205705899936362
# each_iter_error
# 1.2057023040759702
# each_iter_error
# 1.2056978092561792
# each_iter_error
# 1.2056924154807973
# each_iter_error
# 1.205686122754031
# each_iter_error
# 1.2056789310812235
# each_iter_error
# 1.2056708404682865
# each_iter_error
# 1.2056618509215298
# each_iter_error
# 1.2056519624484565
# each_iter_error
# 1.2056411750572238
# each_iter_error
# 1.205629488756415
# each_iter_error
# 1.2056169035553808
# each_iter_error
# 1.2056034194644951
# each_iter_error
# 1.2055890364945583
# tot error
# 183.63373608752923
# each_iter_error
# 0.1584016868683591
# each_iter_error
# 0.1584012713500158
# each_iter_error
# 0.15840071732608862
# each_iter_error
# 0.1584000247975439
# each_iter_error
# 0.15839919376495004
# each_iter_error
# 0.15839822422904604
# each_iter_error
# 0.15839711619108243
# each_iter_error
# 0.15839586965211083
# each_iter_error
# 0.15839448461323968
# each_iter_error
# 0.15839296107557743
# each_iter_error
# 0.15839129904119886
# each_iter_error
# 0.15838949851109874
# each_iter_error
# 0.15838755948701078
# each_iter_error
# 0.1583854819709245
# each_iter_error
# 0.1583832659649147
# tot error
# 183.63517727533295
# each_iter_error
# 1.9125441705499497
# each_iter_error
# 1.9125390885014326
# each_iter_error
# 1.9125323124450233
# each_iter_error
# 1.912523842387543
# each_iter_error
# 1.912513678337632
# each_iter_error
# 1.9125018203048967
# each_iter_error
# 1.9124882683016722
# each_iter_error
# 1.912473022340464
# each_iter_error
# 1.9124560824361652
# each_iter_error
# 1.9124374486052034
# each_iter_error
# 1.9124171208652
# each_iter_error
# 1.9123950992356527
# each_iter_error
# 1.9123713837380478
# each_iter_error
# 1.9123459743943272
# each_iter_error
# 1.9123188712288197
# tot error
# 183.6232253895206
# each_iter_error
# 2.404410532326949
# each_iter_error
# 2.4044050330804794
# each_iter_error
# 2.4043977007579542
# each_iter_error
# 2.4043885353656265
# each_iter_error
# 2.4043775369106584
# each_iter_error
# 2.4043647054027133
# each_iter_error
# 2.4043500408518526
# each_iter_error
# 2.4043335432706385
# each_iter_error
# 2.4043152126731115
# each_iter_error
# 2.4042950490745056
# each_iter_error
# 2.4042730524917033
# each_iter_error
# 2.4042492229432924
# each_iter_error
# 2.4042235604496796
# each_iter_error
# 2.4041960650321244
# each_iter_error
# 2.4041667367140462
# tot error
# 183.60317873790873
# each_iter_error
# 0.9235051946627664
# each_iter_error
# 0.9235031540832779
# each_iter_error
# 0.9235004333133645
# each_iter_error
# 0.9234970323552432
# each_iter_error
# 0.9234929512120402
# each_iter_error
# 0.9234881898867684
# each_iter_error
# 0.9234827483833215
# each_iter_error
# 0.9234766267063321
# each_iter_error
# 0.923469824860291
# each_iter_error
# 0.9234623428512521
# each_iter_error
# 0.9234541806846153
# each_iter_error
# 0.9234453383672019
# each_iter_error
# 0.9234358159060321
# each_iter_error
# 0.9234256133085808
# each_iter_error
# 0.9234147305827776
# tot error
# 183.59313662676755
# each_iter_error
# 1.1297641062953119
# each_iter_error
# 1.129761646899027
# each_iter_error
# 1.1297583677074101
# each_iter_error
# 1.129754268722479
# each_iter_error
# 1.1297493499479287
# each_iter_error
# 1.1297436113876245
# each_iter_error
# 1.1297370530460853
# each_iter_error
# 1.1297296749282566
# each_iter_error
# 1.1297214770405333
# each_iter_error
# 1.1297124593885428
# each_iter_error
# 1.1297026219797033
# each_iter_error
# 1.1296919648216885
# each_iter_error
# 1.1296804879229398
# each_iter_error
# 1.1296681912921258
# each_iter_error
# 1.1296550749389382
# tot error
# 183.58159452930835
# each_iter_error
# 1.124162483440358
# each_iter_error
# 1.1241600092585031
# each_iter_error
# 1.124156710352537
# each_iter_error
# 1.1241525867252733
# each_iter_error
# 1.1241476383797249
# each_iter_error
# 1.1241418653203823
# each_iter_error
# 1.124135267551651
# each_iter_error
# 1.1241278450787604
# each_iter_error
# 1.1241195979077645
# each_iter_error
# 1.1241105260454844
# each_iter_error
# 1.1241006294984288
# each_iter_error
# 1.1240899082748683
# each_iter_error
# 1.124078362383301
# each_iter_error
# 1.1240659918325377
# each_iter_error
# 1.124052796632668
# tot error
# 183.57051536051054
# each_iter_error
# 1.9907670021638353
# each_iter_error
# 1.9907625853089144
# each_iter_error
# 1.9907566961737473
# each_iter_error
# 1.99074933476291
# each_iter_error
# 1.9907405010823993
# each_iter_error
# 1.9907301951387524
# each_iter_error
# 1.990718416940581
# each_iter_error
# 1.9907051664969515
# each_iter_error
# 1.990690443818238
# each_iter_error
# 1.990674248916008
# each_iter_error
# 1.9906565818033357
# each_iter_error
# 1.9906374424942896
# each_iter_error
# 1.9906168310040755
# each_iter_error
# 1.9905947473486663
# each_iter_error
# 1.9905711915458824
# tot error
# 183.5525182810907
# each_iter_error
# 2.464036326114865
# each_iter_error
# 2.464030695569562
# each_iter_error
# 2.464023188181841
# each_iter_error
# 2.464013803957158
# each_iter_error
# 2.4640025429033585
# each_iter_error
# 2.46398940502894
# each_iter_error
# 2.463974390345385
# each_iter_error
# 2.463957498864062
# each_iter_error
# 2.4639387305996365
# each_iter_error
# 2.4639180855670304
# each_iter_error
# 2.463895563783751
# each_iter_error
# 2.4638711652681877
# each_iter_error
# 2.4638448900409458
# each_iter_error
# 2.4638167381233984
# each_iter_error
# 2.4637867095395904
# tot error
# 183.52948843918122
# each_iter_error
# 1.291255595822264
# each_iter_error
# 1.2912527129748241
# each_iter_error
# 1.2912488691815724
# each_iter_error
# 1.2912440644461185
# each_iter_error
# 1.2912382987719866
# each_iter_error
# 1.2912315721639516
# each_iter_error
# 1.291223884627641
# each_iter_error
# 1.291215236169137
# each_iter_error
# 1.291205626795204
# each_iter_error
# 1.291195056513942
# each_iter_error
# 1.29118352533348
# each_iter_error
# 1.2911710332633675
# each_iter_error
# 1.2911575803131257
# each_iter_error
# 1.2911431664944644
# each_iter_error
# 1.2911277918179849
# tot error
# 183.51565352285942
# each_iter_error
# 1.5340705998691533
# each_iter_error
# 1.5340671335461877
# each_iter_error
# 1.534062511786658
# each_iter_error
# 1.5340567345939746
# each_iter_error
# 1.5340498019730546
# each_iter_error
# 1.5340417139298097
# each_iter_error
# 1.5340324704707484
# each_iter_error
# 1.5340220716033457
# each_iter_error
# 1.5340105173361849
# each_iter_error
# 1.533997807678702
# each_iter_error
# 1.5339839426416404
# each_iter_error
# 1.5339689222358572
# each_iter_error
# 1.533952746474057
# each_iter_error
# 1.5339354153692284
# each_iter_error
# 1.533916928935696
# tot error
# 183.49983063490095
# each_iter_error
# 1.1550359373954109
# each_iter_error
# 1.1550333236175447
# each_iter_error
# 1.1550298385839426
# each_iter_error
# 1.1550254822973613
# each_iter_error
# 1.1550202547614958
# each_iter_error
# 1.1550141559806093
# each_iter_error
# 1.155007185960045
# each_iter_error
# 1.1549993447053737
# each_iter_error
# 1.1549906322229901
# each_iter_error
# 1.1549810485199714
# each_iter_error
# 1.1549705936042471
# each_iter_error
# 1.1549592674845712
# each_iter_error
# 1.1549470701698397
# each_iter_error
# 1.1549340016703695
# each_iter_error
# 1.154920061996421
# tot error
# 183.48695540645082
# each_iter_error
# 1.077544294428833
# each_iter_error
# 1.0775418089014295
# each_iter_error
# 1.0775384948686906
# each_iter_error
# 1.0775343523330605
# each_iter_error
# 1.0775293812981204
# each_iter_error
# 1.077523581768105
# each_iter_error
# 1.0775169537480735
# each_iter_error
# 1.0775094972433408
# each_iter_error
# 1.0775012122603869
# each_iter_error
# 1.077492098806033
# each_iter_error
# 1.077482156887811
# each_iter_error
# 1.077471386513821
# each_iter_error
# 1.0774597876933285
# each_iter_error
# 1.0774473604355705
# each_iter_error
# 1.0774341047508642
# tot error
# 183.4753237701795
# each_iter_error
# 0.12497180130253582
# each_iter_error
# 0.12497148452428064
# each_iter_error
# 0.12497106215386111
# each_iter_error
# 0.12497053419153303
# each_iter_error
# 0.12496990063817748
# each_iter_error
# 0.12496916149424919
# each_iter_error
# 0.12496831676028819
# each_iter_error
# 0.12496736643745976
# each_iter_error
# 0.12496631052621865
# each_iter_error
# 0.12496514902798594
# each_iter_error
# 0.12496388194344377
# each_iter_error
# 0.12496250927424057
# each_iter_error
# 0.12496103102111533
# each_iter_error
# 0.1249594471854607
# each_iter_error
# 0.12495775776903884
# tot error
# 183.47411626342102
# each_iter_error
# 0.8456927558009966
# each_iter_error
# 0.8456906095648264
# each_iter_error
# 0.8456877479203513
# each_iter_error
# 0.8456841708704133
# each_iter_error
# 0.845679878418423
# each_iter_error
# 0.8456748705687573
# each_iter_error
# 0.8456691473260776
# each_iter_error
# 0.8456627086957269
# each_iter_error
# 0.8456555546836739
# each_iter_error
# 0.8456476852963419
# each_iter_error
# 0.8456391005416322
# each_iter_error
# 0.8456298004271616
# each_iter_error
# 0.8456197849611726
# each_iter_error
# 0.8456090541532717
# each_iter_error
# 0.845597608012497
# tot error
# 183.46803432157157
# each_iter_error
# 3.413658140836617
# each_iter_error
# 3.413648650490245
# each_iter_error
# 3.413635996707171
# each_iter_error
# 3.4136201794997874
# each_iter_error
# 3.413601198884294
# each_iter_error
# 3.4135790548796194
# each_iter_error
# 3.413553747508786
# each_iter_error
# 3.413525276797486
# each_iter_error
# 3.413493642775677
# each_iter_error
# 3.413458845476214
# each_iter_error
# 3.4134208849351353
# each_iter_error
# 3.4133797611924024
# each_iter_error
# 3.4133354742913866
# each_iter_error
# 3.41328802427887
# each_iter_error
# 3.413237411204136
# tot error
# 183.4379937060531
# each_iter_error
# 1.897789939521374
# each_iter_error
# 1.89778545842546
# each_iter_error
# 1.897779483636043
# each_iter_error
# 1.8977720151581536
# each_iter_error
# 1.8977630529977034
# each_iter_error
# 1.8977525971627642
# each_iter_error
# 1.8977406476617773
# each_iter_error
# 1.897727204504804
# each_iter_error
# 1.897712267703497
# each_iter_error
# 1.89769583727022
# each_iter_error
# 1.897677913219212
# each_iter_error
# 1.897658495565537
# each_iter_error
# 1.8976375843259632
# each_iter_error
# 1.8976151795180272
# each_iter_error
# 1.8975912811610556
# tot error
# 183.4173080427786
# each_iter_error
# 1.1958344417956255
# each_iter_error
# 1.1958316314725437
# each_iter_error
# 1.1958278843792982
# each_iter_error
# 1.1958232005188734
# each_iter_error
# 1.1958175798954187
# each_iter_error
# 1.195811022513567
# each_iter_error
# 1.1958035283792583
# each_iter_error
# 1.1957950974987455
# each_iter_error
# 1.1957857298794181
# each_iter_error
# 1.1957754255290638
# each_iter_error
# 1.1957641844566353
# each_iter_error
# 1.1957520066714835
# each_iter_error
# 1.1957388921839538
# each_iter_error
# 1.1957248410049885
# each_iter_error
# 1.1957098531467238
# tot error
# 183.404275909767
# each_iter_error
# 1.2251972162188451
# each_iter_error
# 1.2251943769089166
# each_iter_error
# 1.2251905911659549
# each_iter_error
# 1.2251858589932851
# each_iter_error
# 1.2251801803953128
# each_iter_error
# 1.225173555376358
# each_iter_error
# 1.2251659839424747
# each_iter_error
# 1.2251574660996027
# each_iter_error
# 1.2251480018550183
# each_iter_error
# 1.2251375912167362
# each_iter_error
# 1.2251262341933113
# each_iter_error
# 1.2251139307942083
# each_iter_error
# 1.225100681029346
# each_iter_error
# 1.2250864849098377
# each_iter_error
# 1.2250713424477055
# tot error
# 183.39175216642582
# each_iter_error
# 1.7204965644400545
# each_iter_error
# 1.7204924887043092
# each_iter_error
# 1.7204870543953916
# each_iter_error
# 1.72048026151748
# each_iter_error
# 1.7204721100768836
# each_iter_error
# 1.7204626000803955
# each_iter_error
# 1.7204517315360874
# each_iter_error
# 1.7204395044537648
# each_iter_error
# 1.7204259188432047
# each_iter_error
# 1.7204109747162875
# each_iter_error
# 1.720394672085888
# each_iter_error
# 1.720377010965791
# each_iter_error
# 1.7203579913713156
# each_iter_error
# 1.7203376133182644
# each_iter_error
# 1.7203158768245146
# tot error
# 183.37513055545406
# each_iter_error
# 2.0704226767329885
# each_iter_error
# 2.070417743426674
# each_iter_error
# 2.0704111656909845
# each_iter_error
# 2.070402943531093
# each_iter_error
# 2.070393076954332
# each_iter_error
# 2.070381565969143
# each_iter_error
# 2.070368410585445
# each_iter_error
# 2.0703536108141805
# each_iter_error
# 2.070337166668196
# each_iter_error
# 2.070319078162072
# each_iter_error
# 2.0702993453110423
# each_iter_error
# 2.070277968132359
# each_iter_error
# 2.070254946644127
# each_iter_error
# 2.070230280866326
# each_iter_error
# 2.070203970820728
# tot error
# 183.35509283099728
# each_iter_error
# 1.3978427368964503
# each_iter_error
# 1.3978394729365107
# each_iter_error
# 1.3978351209941877
# each_iter_error
# 1.3978296810734037
# each_iter_error
# 1.3978231531783365
# each_iter_error
# 1.39781553731504
# each_iter_error
# 1.3978068334898808
# each_iter_error
# 1.3977970417100778
# each_iter_error
# 1.3977861619840155
# each_iter_error
# 1.397774194320732
# each_iter_error
# 1.3977611387305444
# each_iter_error
# 1.3977469952241108
# each_iter_error
# 1.3977317638136242
# each_iter_error
# 1.3977154445117606
# each_iter_error
# 1.3976980373319066
# tot error
# 183.34068203874324
# each_iter_error
# 1.6708549435073792
# each_iter_error
# 1.6708509413537627
# each_iter_error
# 1.6708456051541134
# each_iter_error
# 1.6708389349134052
# each_iter_error
# 1.6708309306368676
# each_iter_error
# 1.6708215923318903
# each_iter_error
# 1.6708109200064882
# each_iter_error
# 1.6707989136701258
# each_iter_error
# 1.6707855733328358
# each_iter_error
# 1.670770899006527
# each_iter_error
# 1.6707548907037904
# each_iter_error
# 1.6707375484387512
# each_iter_error
# 1.6707188722261037
# each_iter_error
# 1.6706988620822756
# each_iter_error
# 1.6706775180247462
# tot error
# 183.32340555274408
# each_iter_error
# 1.1744400155411654
# each_iter_error
# 1.1744371523031418
# each_iter_error
# 1.1744333346566975
# each_iter_error
# 1.1744285626050726
# each_iter_error
# 1.1744228361528144
# each_iter_error
# 1.1744161553050958
# each_iter_error
# 1.1744085200674306
# each_iter_error
# 1.1743999304471515
# each_iter_error
# 1.1743903864515914
# each_iter_error
# 1.1743798880893337
# each_iter_error
# 1.1743684353693027
# each_iter_error
# 1.1743560283019292
# each_iter_error
# 1.1743426668978145
# each_iter_error
# 1.1743283511688105
# each_iter_error
# 1.174313081127309
# tot error
# 183.310310451197
# each_iter_error
# 0.8499075264077192
# each_iter_error
# 0.8499053665984491
# each_iter_error
# 0.8499024868560809
# each_iter_error
# 0.849898887183798
# each_iter_error
# 0.8498945675850393
# each_iter_error
# 0.8498895280638692
# each_iter_error
# 0.8498837686245224
# each_iter_error
# 0.8498772892732518
# each_iter_error
# 0.8498700900155711
# each_iter_error
# 0.8498621708581027
# each_iter_error
# 0.8498535318082645
# each_iter_error
# 0.8498441728738158
# each_iter_error
# 0.849834094063084
# each_iter_error
# 0.849823295385761
# each_iter_error
# 0.8498117768514533
# tot error
# 183.30133343733942
# each_iter_error
# 1.3629471448677748
# each_iter_error
# 1.3629434641388798
# each_iter_error
# 1.3629385565059238
# each_iter_error
# 1.3629324219739374
# each_iter_error
# 1.3629250605497703
# each_iter_error
# 1.3629164722399594
# each_iter_error
# 1.3629066570536281
# each_iter_error
# 1.3628956149998146
# each_iter_error
# 1.3628833460899443
# each_iter_error
# 1.362869850334988
# each_iter_error
# 1.3628551277489294
# each_iter_error
# 1.362839178345439
# each_iter_error
# 1.3628220021403479
# each_iter_error
# 1.362803599149487
# each_iter_error
# 1.362783969391387
# tot error
# 183.28774416129593
# each_iter_error
# 0.2921971174731084
# each_iter_error
# 0.29219632761891035
# each_iter_error
# 0.2921952744811165
# each_iter_error
# 0.29219395806160264
# each_iter_error
# 0.29219237836105094
# each_iter_error
# 0.29219053538179196
# each_iter_error
# 0.2921884291252468
# each_iter_error
# 0.2921860595938597
# each_iter_error
# 0.2921834267895633
# each_iter_error
# 0.2921805307153136
# each_iter_error
# 0.29217737137412314
# each_iter_error
# 0.2921739487686068
# each_iter_error
# 0.2921702629024594
# each_iter_error
# 0.29216631377886415
# each_iter_error
# 0.2921621014020843
# tot error
# 183.28530952188493
# each_iter_error
# 3.6022462319733677
# each_iter_error
# 3.6022361544796695
# each_iter_error
# 3.6022227178344792
# each_iter_error
# 3.602205922050814
# each_iter_error
# 3.6021857671447037
# each_iter_error
# 3.6021622531368394
# each_iter_error
# 3.6021353800502425
# each_iter_error
# 3.6021051479120842
# each_iter_error
# 3.60207155675306
# each_iter_error
# 3.60203460660739
# each_iter_error
# 3.6019942975127606
# each_iter_error
# 3.601950629509872
# each_iter_error
# 3.6019036026438016
# each_iter_error
# 3.601853216962695
# each_iter_error
# 3.6017994725182234
# tot error
# 183.25547019330122
# each_iter_error
# 1.8298681837675872
# each_iter_error
# 1.8298636918761986
# each_iter_error
# 1.8298577026932037
# each_iter_error
# 1.8298502162239174
# each_iter_error
# 1.829841232474621
# each_iter_error
# 1.8298307514534713
# each_iter_error
# 1.8298187731695634
# each_iter_error
# 1.8298052976332997
# each_iter_error
# 1.829790324856674
# each_iter_error
# 1.8297738548527889
# each_iter_error
# 1.8297558876359403
# each_iter_error
# 1.8297364232219593
# each_iter_error
# 1.8297154616282114
# each_iter_error
# 1.8296930028731708
# each_iter_error
# 1.8296690469761074
# tot error
# 183.23521110281368
# each_iter_error
# 1.3143434413840964
# each_iter_error
# 1.3143402629304433
# each_iter_error
# 1.314336024997118
# each_iter_error
# 1.3143307275875316
# each_iter_error
# 1.3143243707063448
# each_iter_error
# 1.3143169543595263
# each_iter_error
# 1.3143084785530164
# each_iter_error
# 1.3142989432947445
# each_iter_error
# 1.3142883485931236
# each_iter_error
# 1.3142766944572202
# each_iter_error
# 1.314263980897266
# each_iter_error
# 1.3142502079243172
# each_iter_error
# 1.3142353755503677
# each_iter_error
# 1.314219483788463
# each_iter_error
# 1.3142025326519047
# tot error
# 183.221109033977
# each_iter_error
# 0.8596702927166291
# each_iter_error
# 0.8596682541245286
# each_iter_error
# 0.8596655360050249
# each_iter_error
# 0.8596621383601075
# each_iter_error
# 0.8596580611933575
# each_iter_error
# 0.8596533045079013
# each_iter_error
# 0.8596478683083717
# each_iter_error
# 0.8596417525990603
# each_iter_error
# 0.8596349573856514
# each_iter_error
# 0.8596274826733747
# each_iter_error
# 0.8596193284693641
# each_iter_error
# 0.8596104947798437
# each_iter_error
# 0.8596009816126866
# each_iter_error
# 0.8595907889756234
# each_iter_error
# 0.8595799168777489
# tot error
# 183.212589393612
# each_iter_error
# 1.951476989121204
# each_iter_error
# 1.9514723637791462
# each_iter_error
# 1.9514661966624658
# each_iter_error
# 1.9514584877759944
# each_iter_error
# 1.9514492371262122
# each_iter_error
# 1.951438444721191
# each_iter_error
# 1.951426110569912
# each_iter_error
# 1.9514122346827207
# each_iter_error
# 1.95139681707127
# each_iter_error
# 1.9513798577481793
# each_iter_error
# 1.9513613567284551
# each_iter_error
# 1.951341314027104
# each_iter_error
# 1.9513197296611224
# each_iter_error
# 1.951296603648757
# each_iter_error
# 1.9512719360095616
# tot error
# 183.19536998144991
# each_iter_error
# 2.6456656759569626
# each_iter_error
# 2.6456589469428025
# each_iter_error
# 2.6456499749319278
# each_iter_error
# 2.6456387599320976
# each_iter_error
# 2.6456253019536007
# each_iter_error
# 2.6456096010083456
# each_iter_error
# 2.645591657110373
# each_iter_error
# 2.6455714702764226
# each_iter_error
# 2.6455490405245996
# each_iter_error
# 2.6455243678753675
# each_iter_error
# 2.645497452351634
# each_iter_error
# 2.6454682939778706
# each_iter_error
# 2.6454368927809924
# each_iter_error
# 2.6454032487897337
# each_iter_error
# 2.645367362035387
# tot error
# 183.17041975739167
# each_iter_error
# 1.343139833268765
# each_iter_error
# 1.3431365116361462
# each_iter_error
# 1.3431320827973252
# each_iter_error
# 1.3431265467562525
# each_iter_error
# 1.3431199035181294
# each_iter_error
# 1.3431121530887253
# each_iter_error
# 1.3431032954753732
# each_iter_error
# 1.3430933306852921
# each_iter_error
# 1.3430822587279465
# each_iter_error
# 1.343070079613227
# each_iter_error
# 1.3430567933514794
# each_iter_error
# 1.3430423999544416
# each_iter_error
# 1.3430268994352446
# each_iter_error
# 1.3430102918072748
# each_iter_error
# 1.3429925770854254
# tot error
# 183.15561565000783
# each_iter_error
# 1.6176404105646327
# each_iter_error
# 1.6176363955991064
# each_iter_error
# 1.6176310423169866
# each_iter_error
# 1.6176243507234176
# each_iter_error
# 1.617616320824112
# each_iter_error
# 1.6176069526268293
# each_iter_error
# 1.6175962461393283
# each_iter_error
# 1.617584201371784
# each_iter_error
# 1.6175708183345705
# each_iter_error
# 1.6175560970399943
# each_iter_error
# 1.617540037501044
# each_iter_error
# 1.6175226397321012
# each_iter_error
# 1.6175039037489682
# each_iter_error
# 1.6174838295681866
# each_iter_error
# 1.6174624172075482
# tot error
# 183.1381821687409
# each_iter_error
# 1.2383253511155203
# each_iter_error
# 1.2383223212556516
# each_iter_error
# 1.2383182814468512
# each_iter_error
# 1.2383132316929277
# each_iter_error
# 1.2383071719978318
# each_iter_error
# 1.2383001023679014
# each_iter_error
# 1.238292022808622
# each_iter_error
# 1.238282933327497
# each_iter_error
# 1.2382728339326547
# each_iter_error
# 1.238261724632622
# each_iter_error
# 1.2382496054378578
# each_iter_error
# 1.2382364763581108
# each_iter_error
# 1.2382223374056878
# each_iter_error
# 1.2382071885923267
# each_iter_error
# 1.2381910299316985
# tot error
# 183.12421561433248
# each_iter_error
# 1.5727092832395897
# each_iter_error
# 1.572705478879385
# each_iter_error
# 1.5727004064039534
# each_iter_error
# 1.5726940658178137
# each_iter_error
# 1.572686457126622
# each_iter_error
# 1.5726775803368582
# each_iter_error
# 1.5726674354564238
# each_iter_error
# 1.572656022493959
# each_iter_error
# 1.5726433414592975
# each_iter_error
# 1.5726293923639219
# each_iter_error
# 1.572614175219428
# each_iter_error
# 1.5725976900389185
# each_iter_error
# 1.5725799368369735
# each_iter_error
# 1.572560915628742
# each_iter_error
# 1.5725406264307082
# tot error
# 183.10763808963338
# each_iter_error
# 0.4825339591086504
# each_iter_error
# 0.48253248243923963
# each_iter_error
# 0.4825305135502731
# each_iter_error
# 0.4825280524441382
# each_iter_error
# 0.48252509912424557
# each_iter_error
# 0.48252165359372157
# each_iter_error
# 0.4825177158566021
# each_iter_error
# 0.48251328591777565
# each_iter_error
# 0.48250836378196027
# each_iter_error
# 0.4825029494546129
# each_iter_error
# 0.48249704294210005
# each_iter_error
# 0.4824906442504471
# each_iter_error
# 0.4824837533865889
# each_iter_error
# 0.4824763703586541
# each_iter_error
# 0.4824684951737481
# tot error
# 183.11168751389067
# each_iter_error
# 4.086799808512183
# each_iter_error
# 4.086788235852907
# each_iter_error
# 4.086772805656324
# each_iter_error
# 4.086753517937495
# each_iter_error
# 4.086730372715749
# each_iter_error
# 4.08670337001422
# each_iter_error
# 4.086672509860364
# each_iter_error
# 4.086637792284591
# each_iter_error
# 4.086599217322828
# each_iter_error
# 4.086556785013897
# each_iter_error
# 4.08651049540066
# each_iter_error
# 4.086460348530238
# each_iter_error
# 4.08640634445436
# each_iter_error
# 4.086348483227482
# each_iter_error
# 4.086286764908721
# tot error
# 183.085026353596
# each_iter_error
# 3.7856753399034915
# each_iter_error
# 3.7856650238541647
# each_iter_error
# 3.785651269133041
# each_iter_error
# 3.7856340757526823
# each_iter_error
# 3.7856134437292326
# each_iter_error
# 3.7855893730823027
# each_iter_error
# 3.78556186383571
# each_iter_error
# 3.7855309160157162
# each_iter_error
# 3.7854965296537557
# each_iter_error
# 3.7854587047831387
# each_iter_error
# 3.7854174414421777
# each_iter_error
# 3.7853727396723116
# each_iter_error
# 3.7853245995181624
# each_iter_error
# 3.7852730210286154
# each_iter_error
# 3.78521800425591
# tot error
# 183.05097840812093
# each_iter_error
# 2.368981607047317
# each_iter_error
# 2.3689759015510674
# each_iter_error
# 2.368968294228921
# each_iter_error
# 2.3689587850867326
# each_iter_error
# 2.3689473741324036
# each_iter_error
# 2.3689340613758816
# each_iter_error
# 2.3689188468281657
# each_iter_error
# 2.368901730502074
# each_iter_error
# 2.3688827124121588
# each_iter_error
# 2.368861792574819
# each_iter_error
# 2.3688389710079036
# each_iter_error
# 2.368814247731251
# each_iter_error
# 2.3687876227657796
# each_iter_error
# 2.368759096134795
# each_iter_error
# 2.3687286678627686
# tot error
# 183.02627458711214
# each_iter_error
# 1.6786184290108679
# each_iter_error
# 1.678614291088195
# each_iter_error
# 1.678608773863516
# each_iter_error
# 1.6786018773415776
# each_iter_error
# 1.6785936015283767
# each_iter_error
# 1.6785839464312744
# each_iter_error
# 1.678572912058769
# each_iter_error
# 1.6785604984210636
# each_iter_error
# 1.678546705528504
# each_iter_error
# 1.6785315333933681
# each_iter_error
# 1.6785149820292702
# each_iter_error
# 1.6784970514505062
# each_iter_error
# 1.6784777416727366
# each_iter_error
# 1.6784570527137248
# each_iter_error
# 1.678434984590666
# tot error
# 183.008308683575
# each_iter_error
# 1.2311090632184971
# each_iter_error
# 1.2311060340606446
# each_iter_error
# 1.2311019951876858
# each_iter_error
# 1.2310969466034294
# each_iter_error
# 1.2310908883124227
# each_iter_error
# 1.2310838203205208
# each_iter_error
# 1.231075742633152
# each_iter_error
# 1.2310666552580471
# each_iter_error
# 1.2310565582031359
# each_iter_error
# 1.2310454514772857
# each_iter_error
# 1.2310333350895917
# each_iter_error
# 1.2310202090515645
# each_iter_error
# 1.2310060733740613
# each_iter_error
# 1.2309909280695308
# each_iter_error
# 1.230974773150848
# tot error
# 182.99565960797176
# each_iter_error
# 2.2547333638586338
# each_iter_error
# 2.2547281403596173
# each_iter_error
# 2.2547211756999843
# each_iter_error
# 2.2547124698853622
# each_iter_error
# 2.2547020229232544
# each_iter_error
# 2.254689834822244
# each_iter_error
# 2.2546759055925065
# each_iter_error
# 2.2546602352459217
# each_iter_error
# 2.254642823795848
# each_iter_error
# 2.2546236712567804
# each_iter_error
# 2.254602777645374
# each_iter_error
# 2.254580142979137
# each_iter_error
# 2.2545557672773384
# each_iter_error
# 2.254529650560869
# each_iter_error
# 2.254501792852352
# tot error
# 182.97502858779637
# each_iter_error
# 2.878276534015157
# each_iter_error
# 2.8782693164466195
# each_iter_error
# 2.878259693029463
# each_iter_error
# 2.8782476637716172
# each_iter_error
# 2.878233228683513
# each_iter_error
# 2.8782163877775986
# each_iter_error
# 2.878197141068199
# each_iter_error
# 2.8781754885718556
# each_iter_error
# 2.8781514303083497
# each_iter_error
# 2.8781249662980883
# each_iter_error
# 2.878096096564917
# each_iter_error
# 2.878064821134103
# each_iter_error
# 2.878031140033528
# each_iter_error
# 2.8779950532932617
# each_iter_error
# 2.8779565609451367
# tot error
# 182.9479176276619
# each_iter_error
# 1.8808602532493524
# each_iter_error
# 1.88085562138167
# each_iter_error
# 1.8808494455638538
# each_iter_error
# 1.8808417258007069
# each_iter_error
# 1.8808324620993346
# each_iter_error
# 1.880821654467411
# each_iter_error
# 1.8808093029142583
# each_iter_error
# 1.8807954074503357
# each_iter_error
# 1.8807799680878077
# each_iter_error
# 1.8807629848395493
# each_iter_error
# 1.880744457720482
# each_iter_error
# 1.8807243867464365
# each_iter_error
# 1.8807027719345513
# each_iter_error
# 1.8806796133033856
# each_iter_error
# 1.8806549108728632
# tot error
# 182.92803585162054
# each_iter_error
# 2.178070751506567
# each_iter_error
# 2.178065262751119
# each_iter_error
# 2.1780579444168495
# each_iter_error
# 2.1780487965106943
# each_iter_error
# 2.178037819040526
# each_iter_error
# 2.178025012015837
# each_iter_error
# 2.17801037544848
# each_iter_error
# 2.177993909351585
# each_iter_error
# 2.1779756137396475
# each_iter_error
# 2.1779554886295216
# each_iter_error
# 2.1779335340391413
# each_iter_error
# 2.1779097499880606
# each_iter_error
# 2.177884136498392
# each_iter_error
# 2.17785669359273
# each_iter_error
# 2.177827421296371
# tot error
# 182.90489275382535
# each_iter_error
# 1.6640253468036121
# each_iter_error
# 1.6640210517439868
# each_iter_error
# 1.6640153250032768
# each_iter_error
# 1.664008166587223
# each_iter_error
# 1.6639995765021922
# each_iter_error
# 1.6639895547563412
# each_iter_error
# 1.6639781013587935
# each_iter_error
# 1.663965216319923
# each_iter_error
# 1.6639508996518089
# each_iter_error
# 1.6639351513676957
# each_iter_error
# 1.6639179714820216
# each_iter_error
# 1.6638993600105323
# each_iter_error
# 1.6638793169701387
# each_iter_error
# 1.6638578423795138
# each_iter_error
# 1.6638349362585245
# tot error
# 182.88538060785652
# each_iter_error
# 1.5090674525842758
# each_iter_error
# 1.5090635493704667
# each_iter_error
# 1.5090583450911765
# each_iter_error
# 1.5090518397511516
# each_iter_error
# 1.5090440333570143
# each_iter_error
# 1.5090349259152163
# each_iter_error
# 1.5090245174351935
# each_iter_error
# 1.5090128079259273
# each_iter_error
# 1.5089997973985874
# each_iter_error
# 1.5089854858653098
# each_iter_error
# 1.5089698733394243
# each_iter_error
# 1.5089529598353977
# each_iter_error
# 1.5089347453686628
# each_iter_error
# 1.508915229956358
# each_iter_error
# 1.508894413616133
# tot error
# 182.86888334543738
# each_iter_error
# 0.676536473250394
# each_iter_error
# 0.676534530291633
# each_iter_error
# 0.6765319396836844
# each_iter_error
# 0.6765287014294472
# each_iter_error
# 0.6765248155328436
# each_iter_error
# 0.6765202819976821
# each_iter_error
# 0.6765151008295902
# each_iter_error
# 0.6765092720335133
# each_iter_error
# 0.6765027956158747
# each_iter_error
# 0.6764956715836092
# each_iter_error
# 0.6764878999437656
# each_iter_error
# 0.676479480704927
# each_iter_error
# 0.6764704138752791
# each_iter_error
# 0.6764606994644282
# each_iter_error
# 0.6764503374828337
# tot error
# 182.8632879425078
# each_iter_error
# 2.487580569908914
# each_iter_error
# 2.4875738505863296
# each_iter_error
# 2.4875648914992325
# each_iter_error
# 2.487553692657116
# each_iter_error
# 2.4875402540708933
# each_iter_error
# 2.4875245757534685
# each_iter_error
# 2.487506657720644
# each_iter_error
# 2.4874864999898136
# each_iter_error
# 2.4874641025803044
# each_iter_error
# 2.4874394655143988
# each_iter_error
# 2.4874125888158574
# each_iter_error
# 2.487383472510942
# each_iter_error
# 2.4873521166277897
# each_iter_error
# 2.4873185211966984
# each_iter_error
# 2.4872826862504667
# tot error
# 182.84562145928285
# each_iter_error
# 3.8534172546769128
# each_iter_error
# 3.853406269267964
# each_iter_error
# 3.8533916220687274
# each_iter_error
# 3.853373313093698
# each_iter_error
# 3.853351342360611
# each_iter_error
# 3.8533257098922036
# each_iter_error
# 3.853296415713828
# each_iter_error
# 3.853263459856066
# each_iter_error
# 3.85322684235274
# each_iter_error
# 3.8531865632424456
# each_iter_error
# 3.853142622566679
# each_iter_error
# 3.8530950203719954
# each_iter_error
# 3.8530437567084164
# each_iter_error
# 3.8529888316302845
# each_iter_error
# 3.852930245195239
# tot error
# 182.81040026962913
# each_iter_error
# 2.4239330153594096
# each_iter_error
# 2.42392692352783
# each_iter_error
# 2.423918801092725
# each_iter_error
# 2.423908648060774
# each_iter_error
# 2.4238964644408156
# each_iter_error
# 2.4238822502434516
# each_iter_error
# 2.4238660054809884
# each_iter_error
# 2.42384773016812
# each_iter_error
# 2.42382742432099
# each_iter_error
# 2.423805087957959
# each_iter_error
# 2.4237807210984386
# each_iter_error
# 2.423754323764996
# each_iter_error
# 2.423725895981164
# each_iter_error
# 2.4236954377723237
# each_iter_error
# 2.423662949166385
# tot error
# 182.78410664979324
# each_iter_error
# 1.9275408918663288
# each_iter_error
# 1.9275359363462314
# each_iter_error
# 1.927529328992449
# each_iter_error
# 1.9275210698111493
# each_iter_error
# 1.9275111588097218
# each_iter_error
# 1.927499595997375
# each_iter_error
# 1.9274863813845116
# each_iter_error
# 1.9274715149830683
# each_iter_error
# 1.927454996807171
# each_iter_error
# 1.927436826871599
# each_iter_error
# 1.9274170051931208
# each_iter_error
# 1.9273955317896423
# each_iter_error
# 1.9273724066814566
# each_iter_error
# 1.927347629889141
# each_iter_error
# 1.9273212014360865
# tot error
# 182.76268223210735
# each_iter_error
# 1.4027497389545829
# each_iter_error
# 1.4027462658657157
# each_iter_error
# 1.4027416350857322
# each_iter_error
# 1.4027358466185547
# each_iter_error
# 1.402728900469242
# each_iter_error
# 1.4027207966443882
# each_iter_error
# 1.4027115351512407
# each_iter_error
# 1.402701115997445
# each_iter_error
# 1.4026895391926928
# each_iter_error
# 1.402676804747216
# each_iter_error
# 1.4026629126722128
# each_iter_error
# 1.4026478629793928
# each_iter_error
# 1.4026316556825975
# each_iter_error
# 1.4026142907958672
# each_iter_error
# 1.4025957683341232
# tot error
# 182.74822858163964
# each_iter_error
# 2.1688155000801146
# each_iter_error
# 2.168809984375173
# each_iter_error
# 2.1688026301088996
# each_iter_error
# 2.168793437288258
# each_iter_error
# 2.168782405920666
# each_iter_error
# 2.168769536016981
# each_iter_error
# 2.1687548275880317
# each_iter_error
# 2.168738280647915
# each_iter_error
# 2.1687198952104723
# each_iter_error
# 2.1686996712927566
# each_iter_error
# 2.1686776089132422
# each_iter_error
# 2.168653708091256
# each_iter_error
# 2.1686279688483694
# each_iter_error
# 2.168600391207889
# each_iter_error
# 2.168570975194939
# tot error
# 182.7277449860048
# each_iter_error
# 2.6506748418881614
# each_iter_error
# 2.6506678473830334
# each_iter_error
# 2.6506585213848837
# each_iter_error
# 2.6506468639023524
# each_iter_error
# 2.6506328749464103
# each_iter_error
# 2.6506165545296483
# each_iter_error
# 2.6505979026677835
# each_iter_error
# 2.6505769193783806
# each_iter_error
# 2.6505536046817895
# each_iter_error
# 2.6505279585998096
# each_iter_error
# 2.650499981156912
# each_iter_error
# 2.650469672380183
# each_iter_error
# 2.6504370322982993
# each_iter_error
# 2.6504020609429233
# each_iter_error
# 2.6503647583476777
# tot error
# 182.7015002466244
# each_iter_error
# 1.4983116322500791
# each_iter_error
# 1.4983077478758275
# each_iter_error
# 1.4983025687158147
# each_iter_error
# 1.4982960947748154
# each_iter_error
# 1.498288326058713
# each_iter_error
# 1.498279262575096
# each_iter_error
# 1.4982689043324342
# each_iter_error
# 1.498257251340135
# each_iter_error
# 1.4982443036093116
# each_iter_error
# 1.4982300611517303
# each_iter_error
# 1.4982145239807778
# each_iter_error
# 1.4981976921102955
# each_iter_error
# 1.4981795655568249
# each_iter_error
# 1.4981601443362536
# each_iter_error
# 1.498139428466743
# tot error
# 182.6841283881226
# each_iter_error
# 1.9025290662282544
# each_iter_error
# 1.9025241162961208
# each_iter_error
# 1.902517516393317
# each_iter_error
# 1.9025092665260672
# each_iter_error
# 1.9024993667020453
# each_iter_error
# 1.9024878169303179
# each_iter_error
# 1.9024746172220546
# each_iter_error
# 1.9024597675891073
# each_iter_error
# 1.902443268045971
# each_iter_error
# 1.9024251186080505
# each_iter_error
# 1.9024053192921713
# each_iter_error
# 1.9023838701169495
# each_iter_error
# 1.9023607711029058
# each_iter_error
# 1.9023360222713848
# each_iter_error
# 1.9023096236460333
# tot error
# 182.66260788643038
# each_iter_error
# 1.670675255226712
# each_iter_error
# 1.670670883344286
# each_iter_error
# 1.6706650541736963
# each_iter_error
# 1.6706577677209111
# each_iter_error
# 1.6706490239920697
# each_iter_error
# 1.670638822995869
# each_iter_error
# 1.670627164741802
# each_iter_error
# 1.6706140492405837
# each_iter_error
# 1.67059947650489
# each_iter_error
# 1.6705834465481928
# each_iter_error
# 1.670565959385442
# each_iter_error
# 1.6705470150331223
# each_iter_error
# 1.6705266135092813
# each_iter_error
# 1.670504754832649
# each_iter_error
# 1.6704814390236322
# tot error
# 182.6428481564003
# each_iter_error
# 1.6643674727901612
# each_iter_error
# 1.6643630659664268
# each_iter_error
# 1.6643571902079088
# each_iter_error
# 1.664349845520178
# each_iter_error
# 1.6643410319105385
# each_iter_error
# 1.6643307493872896
# each_iter_error
# 1.6643189979606063
# each_iter_error
# 1.6643057776411183
# each_iter_error
# 1.664291088442127
# each_iter_error
# 1.6642749303774451
# each_iter_error
# 1.6642573034623354
# each_iter_error
# 1.664238207713879
# each_iter_error
# 1.6642176431500104
# each_iter_error
# 1.6641956097904824
# each_iter_error
# 1.6641721076561282
# tot error
# 182.62474251768356
# each_iter_error
# 0.5441611677667311
# each_iter_error
# 0.5441595621559827
# each_iter_error
# 0.5441574213443232
# each_iter_error
# 0.5441547453351632
# each_iter_error
# 0.5441515341310605
# each_iter_error
# 0.5441477877359375
# each_iter_error
# 0.5441435061538868
# each_iter_error
# 0.5441386893898539
# each_iter_error
# 0.5441333374486703
# each_iter_error
# 0.5441274503362479
# each_iter_error
# 0.5441210280591804
# each_iter_error
# 0.5441140706241185
# each_iter_error
# 0.5441065780383383
# each_iter_error
# 0.5440985503098545
# each_iter_error
# 0.5440899874474212
# tot error
# 182.61994962658892
# each_iter_error
# 2.1733187564927334
# each_iter_error
# 2.173312698423217
# each_iter_error
# 2.173304621007503
# each_iter_error
# 2.173294524253663
# each_iter_error
# 2.1732824081726108
# each_iter_error
# 2.1732682727766246
# each_iter_error
# 2.173252118080427
# each_iter_error
# 2.173233944100332
# each_iter_error
# 2.1732137508548135
# each_iter_error
# 2.173191538364563
# each_iter_error
# 2.1731673066515214
# each_iter_error
# 2.1731410557406434
# each_iter_error
# 2.1731127856585317
# each_iter_error
# 2.1730824964326985
# each_iter_error
# 2.1730501880948623
# tot error
# 182.60497365342232
# each_iter_error
# 3.9412088460151153
# each_iter_error
# 3.941197125437043
# each_iter_error
# 3.94118149801551
# each_iter_error
# 3.9411619637662625
# each_iter_error
# 3.941138522709707
# each_iter_error
# 3.9411111748704
# each_iter_error
# 3.941079920277616
# each_iter_error
# 3.941044758964267
# each_iter_error
# 3.9410056909684954
# each_iter_error
# 3.9409627163321375
# each_iter_error
# 3.9409158351016345
# each_iter_error
# 3.9408650473278044
# each_iter_error
# 3.9408103530657286
# each_iter_error
# 3.9407517523744673
# each_iter_error
# 3.9406892453183673
# tot error
# 182.57246332058
# each_iter_error
# 2.496713087880437
# each_iter_error
# 2.496706259068276
# each_iter_error
# 2.4966971539939493
# each_iter_error
# 2.4966857726661544
# each_iter_error
# 2.496672115095464
# each_iter_error
# 2.4966561812950374
# each_iter_error
# 2.496637971280421
# each_iter_error
# 2.496617485068782
# each_iter_error
# 2.4965947226803564
# each_iter_error
# 2.4965696841371994
# each_iter_error
# 2.4965423694637536
# each_iter_error
# 2.496512778686764
# each_iter_error
# 2.4964809118349933
# each_iter_error
# 2.496446768939819
# each_iter_error
# 2.496410350034722
# tot error
# 182.54489666678822
# each_iter_error
# 1.2231178550927098
# each_iter_error
# 1.2231146637037114
# each_iter_error
# 1.2231104085232403
# each_iter_error
# 1.223105089555446
# each_iter_error
# 1.2230987068055583
# each_iter_error
# 1.2230912602796309
# each_iter_error
# 1.2230827499844565
# each_iter_error
# 1.2230731759283913
# each_iter_error
# 1.2230625381202458
# each_iter_error
# 1.223050836570252
# each_iter_error
# 1.2230380712889541
# each_iter_error
# 1.2230242422884032
# each_iter_error
# 1.2230093495812753
# each_iter_error
# 1.2229933931816959
# each_iter_error
# 1.2229763731041032
# tot error
# 182.53110280213673
# each_iter_error
# 0.8967946741515505
# each_iter_error
# 0.8967924044075346
# each_iter_error
# 0.8967893780854581
# each_iter_error
# 0.8967855951883905
# each_iter_error
# 0.8967810557204245
# each_iter_error
# 0.896775759685255
# each_iter_error
# 0.8967697070880547
# each_iter_error
# 0.8967628979342805
# each_iter_error
# 0.8967553322303843
# each_iter_error
# 0.8967470099829029
# each_iter_error
# 0.8967379311996808
# each_iter_error
# 0.8967280958885055
# each_iter_error
# 0.8967175040587279
# each_iter_error
# 0.896706155719329
# each_iter_error
# 0.8966940508807397
# tot error
# 182.52174865325213
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 aug_data = synthesize(ori_data)
# ----> 2 synth_data = calibration(ori_data, aug_data)
#
# File ~/Documents/GitHub/DS2/calibration.py:62, in calibration(ori_data, aug_data, iter, lr)
#      59     print(diff_tot(lamb, weights, aug_data, desired_means, n))
#      61 # compare each row
# ---> 62 rst = np.array([aug_data[np.random.choice(len(aug_data), size=len(aug_data), p=weights_calib, replace=True)].mean(axis=0) for _ in range(100)])
#      63 print("rst:" , rst)
#      65 # tot_mean
#
# File ~/Documents/GitHub/DS2/calibration.py:62, in <listcomp>(.0)
#      59     print(diff_tot(lamb, weights, aug_data, desired_means, n))
#      61 # compare each row
# ---> 62 rst = np.array([aug_data[np.random.choice(len(aug_data), size=len(aug_data), p=weights_calib, replace=True)].mean(axis=0) for _ in range(100)])
#      63 print("rst:" , rst)
#      65 # tot_mean
#
# File numpy/random/mtrand.pyx:974, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1
